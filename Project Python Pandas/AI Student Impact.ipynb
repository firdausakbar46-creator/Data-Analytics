# %% [markdown]
# # Project 5

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\data analytics project 1\project analysis python\ai_student_impact_dataset (1).csv")
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  object
#  2   Year_of_Study               50000 non-null  object
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  object
#  6   Prompt_Engineering_Skill    50000 non-null  object
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  object
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Major_Category                0
# Year_of_Study                 0
# Pre_Semester_GPA              0
# Weekly_GenAI_Hours            0
# Primary_Use_Case              0
# Prompt_Engineering_Skill      0
# Tool_Diversity                0
# Paid_Subscription             0
# Traditional_Study_Hours       0
# Perceived_AI_Dependency       0
# Institutional_Policy          0
# Anxiety_Level_During_Exams    0
# Post_Semester_GPA             0
# Skill_Retention_Score         0
# Burnout_Risk_Level            0
# dtype: int64

# %%
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.rename(columns= {'Major_Category':'Bidang Kategori','Year_of_Study':'Angkatan','Pre_Semester_GPA':'IPK Per Semester'})
# Out:
#        Student_ID Bidang Kategori   Angkatan  IPK Per Semester  \
# 0          100001      Humanities     Senior             2.418
# 1          100002         Medical     Junior             3.821
# 2          100003        Business   Freshman             3.398
# 3          100004        Business     Senior             3.789
# 4          100005            STEM  Sophomore             3.635
# ...           ...             ...        ...               ...
# 49995      149996        Business     Senior             2.899
# 49996      149997            STEM     Senior             2.870
# 49997      149998        Business     Senior             3.177
# 49998      149999        Business     Junior             3.398
# 49999      150000            Arts  Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df['Anxiety_Level_During_Exams'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50000 entries, 0 to 49999
# Series name: Anxiety_Level_During_Exams
# Non-Null Count  Dtype
# --------------  -----
# 50000 non-null  int64
# dtypes: int64(1)
# memory usage: 390.8 KB

# %%
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
def categorize(item):
    if item in ['Humanities','Business','Arts']:
        return "Social"
    elif item in ['STEM','Medical']:
        return "Hard Science"
    return "Other"

df["Category"] = df["Major_Category"].apply(categorize)
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
pivot1 = df.pivot_table(index= 'Year_of_Study', values = 'Post_Semester_GPA', aggfunc= 'mean')
pivot
# Out:
#                Post_Semester_GPA
# Year_of_Study
# Freshman                3.277863
# Graduate                3.392435
# Junior                  3.372006
# Senior                  3.390221
# Sophomore               3.327146

# %%
pivot.plot(kind = 'bar', figsize= (7,5), stacked= True, ylabel= 'Post_Semester_GPA', xlabel= 'Year_of_Study')
# Out:
# <Axes: xlabel='Year_of_Study', ylabel='Post_Semester_GPA'>

# %%
pivot2 = df.pivot_table(index= 'Major_Category', values= 'Anxiety_Level_During_Exams',aggfunc='mean')
pivot2
# Out:
#                 Anxiety_Level_During_Exams
# Major_Category
# Arts                              4.174279
# Business                          4.250917
# Humanities                        4.142485
# Medical                           4.227610
# STEM                              4.428979

# %%
pivot2.plot.barh(stacked= True, figsize= (7,5))
# Out:
# <Axes: ylabel='Major_Category'>

# %%
pivot3 = df.pivot_table(index= 'Major_Category', values= 'Traditional_Study_Hours', aggfunc= 'mean')
pivot3
# Out:
#                 Traditional_Study_Hours
# Major_Category
# Arts                          11.352412
# Business                      11.205092
# Humanities                    11.336752
# Medical                       11.365145
# STEM                          11.004719

# %%
pivot3.plot.pie(y= 'Traditional_Study_Hours', figsize= (7,5))
# Out:
# <Axes: ylabel='Traditional_Study_Hours'>
