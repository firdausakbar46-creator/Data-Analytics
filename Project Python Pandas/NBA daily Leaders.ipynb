# %% [markdown]
# # Project 2

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\data analytics project 1\project analysis python\nba_dailyleaders_full.csv")
df
# Out:
#                         Player   Tm  Opp Result     MP  FG  FGA    FG%  3P  \
# 0                  Luka Dončić  LAL  GSW      L  40:59  17   27  0.630   2
# 1               Alperen Şengün  HOU  OKC      L  48:53  12   24  0.500   5
# 2                 Jimmy Butler  GSW  LAL      W  34:44   7   14  0.500   1
# 3      Shai Gilgeous-Alexander  OKC  HOU      W  47:13  12   26  0.462   1
# 4                Austin Reaves  LAL  GSW      L  36:20   9   16  0.563   1
# ...                        ...  ...  ...    ...    ...  ..  ...    ...  ..
# 28563             Nikola Topić  OKC  SAS      W   0:46   0    0    NaN   0
# 28564            Aaron Wiggins  OKC  SAS      W   0:46   0    0    NaN   0
# 28565            Mason Plumlee  SAS  OKC      L   2:13   0    0    NaN   0
# 28566          Bismack Biyombo  SAS  OKC      L   2:13   0    0    NaN   0
# 28567              Luke Kornet  SAS  OKC      L   8:09   0    1  0.000   0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28568 entries, 0 to 28567
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  28568 non-null  object
#  1   Tm      28568 non-null  object
#  2   Opp     28568 non-null  object
#  3   Result  28568 non-null  object
#  4   MP      28568 non-null  object
#  5   FG      28568 non-null  int64
#  6   FGA     28568 non-null  int64
#  7   FG%     27069 non-null  float64
#  8   3P      28568 non-null  int64
#  9   3PA     28568 non-null  int64
#  10  3P%     22822 non-null  float64
#  11  FT      28568 non-null  int64
#  12  FTA     28568 non-null  int64
#  13  FT%     15952 non-null  float64
#  14  ORB     28568 non-null  int64
#  15  DRB     28568 non-null  int64
#  16  TRB     28568 non-null  int64
#  17  AST     28568 non-null  int64
#  18  STL     28568 non-null  int64
#  19  BLK     28568 non-null  int64
#  20  TOV     28568 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  FG           FGA           FG%            3P           3PA  \
# count  28568.000000  28568.000000  27069.000000  28568.000000  28568.000000
# mean       3.844336      8.179222      0.459479      1.216571      3.389492
# std        3.163654      5.853213      0.238910      1.481347      3.022530
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      4.000000      0.333000      0.000000      1.000000
# 50%        3.000000      7.000000      0.471000      1.000000      3.000000
# 75%        6.000000     12.000000      0.600000      2.000000      5.000000
# max       20.000000     45.000000      1.000000     12.000000     22.000000
#
#                 3P%            FT           FTA           FT%           ORB  \
# count  22822.000000  28568.000000  28568.000000  15952.000000  28568.000000
# mean       0.332069      1.696584      2.169490      0.767912      1.046696
# ...

# %%
df
# Out:
#                         Player   Tm  Opp Result     MP  FG  FGA    FG%  3P  \
# 0                  Luka Dončić  LAL  GSW      L  40:59  17   27  0.630   2
# 1               Alperen Şengün  HOU  OKC      L  48:53  12   24  0.500   5
# 2                 Jimmy Butler  GSW  LAL      W  34:44   7   14  0.500   1
# 3      Shai Gilgeous-Alexander  OKC  HOU      W  47:13  12   26  0.462   1
# 4                Austin Reaves  LAL  GSW      L  36:20   9   16  0.563   1
# ...                        ...  ...  ...    ...    ...  ..  ...    ...  ..
# 28563             Nikola Topić  OKC  SAS      W   0:46   0    0    NaN   0
# 28564            Aaron Wiggins  OKC  SAS      W   0:46   0    0    NaN   0
# 28565            Mason Plumlee  SAS  OKC      L   2:13   0    0    NaN   0
# 28566          Bismack Biyombo  SAS  OKC      L   2:13   0    0    NaN   0
# 28567              Luke Kornet  SAS  OKC      L   8:09   0    1  0.000   0
#
# ...

# %%
df.isnull().sum()
# Out:
# Player        0
# Tm            0
# Opp           0
# Result        0
# MP            0
# FG            0
# FGA           0
# FG%        1499
# 3P            0
# 3PA           0
# 3P%        5746
# FT            0
# FTA           0
# FT%       12616
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# +/-          30
# GmSc          0
# Date          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 28563    False
# 28564    False
# 28565    False
# 28566    False
# 28567    False
# Length: 28568, dtype: bool

# %%
df
# Out:
#                         Player   Tm  Opp Result     MP  FG  FGA    FG%  3P  \
# 0                  Luka Dončić  LAL  GSW      L  40:59  17   27  0.630   2
# 1               Alperen Şengün  HOU  OKC      L  48:53  12   24  0.500   5
# 2                 Jimmy Butler  GSW  LAL      W  34:44   7   14  0.500   1
# 3      Shai Gilgeous-Alexander  OKC  HOU      W  47:13  12   26  0.462   1
# 4                Austin Reaves  LAL  GSW      L  36:20   9   16  0.563   1
# ...                        ...  ...  ...    ...    ...  ..  ...    ...  ..
# 28563             Nikola Topić  OKC  SAS      W   0:46   0    0    NaN   0
# 28564            Aaron Wiggins  OKC  SAS      W   0:46   0    0    NaN   0
# 28565            Mason Plumlee  SAS  OKC      L   2:13   0    0    NaN   0
# 28566          Bismack Biyombo  SAS  OKC      L   2:13   0    0    NaN   0
# 28567              Luke Kornet  SAS  OKC      L   8:09   0    1  0.000   0
#
# ...

# %%
df.set_index("Player")
# Out:
#                           Tm  Opp Result     MP  FG  FGA    FG%  3P  3PA  \
# Player
# Luka Dončić              LAL  GSW      L  40:59  17   27  0.630   2   10
# Alperen Şengün           HOU  OKC      L  48:53  12   24  0.500   5    8
# Jimmy Butler             GSW  LAL      W  34:44   7   14  0.500   1    2
# Shai Gilgeous-Alexander  OKC  HOU      W  47:13  12   26  0.462   1    9
# Austin Reaves            LAL  GSW      L  36:20   9   16  0.563   1    5
# ...                      ...  ...    ...    ...  ..  ...    ...  ..  ...
# Nikola Topić             OKC  SAS      W   0:46   0    0    NaN   0    0
# Aaron Wiggins            OKC  SAS      W   0:46   0    0    NaN   0    0
# Mason Plumlee            SAS  OKC      L   2:13   0    0    NaN   0    0
# Bismack Biyombo          SAS  OKC      L   2:13   0    0    NaN   0    0
# Luke Kornet              SAS  OKC      L   8:09   0    1  0.000   0    0
#
#                            3P%  ...  TRB  AST  STL  BLK  TOV  PF  PTS   +/-  \
# ...

# %%
df.pivot_table(index = 'Player', values = 'FG%', aggfunc='mean')
# Out:
#                       FG%
# Player
# A.J. Green       0.410205
# A.J. Lawson      0.293480
# AJ Johnson       0.254025
# Aaron Gordon     0.450615
# Aaron Holiday    0.406068
# ...                   ...
# Zach LaVine      0.468000
# Zeke Nnaji       0.479543
# Ziaire Williams  0.403821
# Zion Williamson  0.600419
# Zyon Pullin      0.833500
#
# [582 rows x 1 columns]

# %%
df.rename(columns= {'Tm':'Team', 'Opp':'Adversary'})
# Out:
#                         Player Team Adversary Result     MP  FG  FGA    FG%  \
# 0                  Luka Dončić  LAL       GSW      L  40:59  17   27  0.630
# 1               Alperen Şengün  HOU       OKC      L  48:53  12   24  0.500
# 2                 Jimmy Butler  GSW       LAL      W  34:44   7   14  0.500
# 3      Shai Gilgeous-Alexander  OKC       HOU      W  47:13  12   26  0.462
# 4                Austin Reaves  LAL       GSW      L  36:20   9   16  0.563
# ...                        ...  ...       ...    ...    ...  ..  ...    ...
# 28563             Nikola Topić  OKC       SAS      W   0:46   0    0    NaN
# 28564            Aaron Wiggins  OKC       SAS      W   0:46   0    0    NaN
# 28565            Mason Plumlee  SAS       OKC      L   2:13   0    0    NaN
# 28566          Bismack Biyombo  SAS       OKC      L   2:13   0    0    NaN
# 28567              Luke Kornet  SAS       OKC      L   8:09   0    1  0.000
#
# ...
