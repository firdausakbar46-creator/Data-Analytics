# %% [markdown]
# # Project 4

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\data analytics project 1\project analysis python\Job Posts.csv")
df
# Out:
#       Unnamed: 0                                          Job_Title  \
# 0              0                         Data Scientist (NiFi, DHF)
# 1              1            Data Scientist - Defense & Intelligence
# 2              2  Fall 2019/Winter 2020 Applied Science Machine ...
# 3              3  Applied Scientist Fall/Winter 2019 Internship ...
# 4              4                Data Scientist/Engineer (HDF, NiFi)
# ...          ...                                                ...
# 9062        9062                   Senior Business Services Analyst
# 9063        9063      AVP of Corporate Strategy & Business Strategy
# 9064        9064                Business Analyst - Registered Nurse
# 9065        9065                                    Systems Analyst
# 9066        9066  Sales & Marketing Team Lead - Competative Spor...
#
#                                         Job_Description  \
# 0     EducationBachelor's DegreeSkillsSQLTime Manage...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9067 entries, 0 to 9066
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9067 non-null   int64
#  1   Job_Title        9067 non-null   object
#  2   Job_Description  9067 non-null   object
#  3   Job_Link         9067 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 283.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Job_Title          0
# Job_Description    0
# Job_Link           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9062    False
# 9063    False
# 9064    False
# 9065    False
# 9066    False
# Length: 9067, dtype: bool

# %%
df.set_index('Job_Title')
# Out:
#                                                     Unnamed: 0  \
# Job_Title
# Data Scientist (NiFi, DHF)                                   0
# Data Scientist - Defense & Intelligence                      1
# Fall 2019/Winter 2020 Applied Science Machine L...           2
# Applied Scientist Fall/Winter 2019 Internship -...           3
# Data Scientist/Engineer (HDF, NiFi)                          4
# ...                                                        ...
# Senior Business Services Analyst                          9062
# AVP of Corporate Strategy & Business Strategy             9063
# Business Analyst - Registered Nurse                       9064
# Systems Analyst                                           9065
# Sales & Marketing Team Lead - Competative Sport...        9066
#
#                                                                                       Job_Description  \
# Job_Title
# ...

# %%
df2 = df.rename(columns= {'Job_Title': 'Nama Pekerjaan', 'Job_Description':'Deskripsi Pekerjaan', 'Job_Link': 'Tautan Pekerjaan'})
df2
# Out:
#       Unnamed: 0                                     Nama Pekerjaan  \
# 0              0                         Data Scientist (NiFi, DHF)
# 1              1            Data Scientist - Defense & Intelligence
# 2              2  Fall 2019/Winter 2020 Applied Science Machine ...
# 3              3  Applied Scientist Fall/Winter 2019 Internship ...
# 4              4                Data Scientist/Engineer (HDF, NiFi)
# ...          ...                                                ...
# 9062        9062                   Senior Business Services Analyst
# 9063        9063      AVP of Corporate Strategy & Business Strategy
# 9064        9064                Business Analyst - Registered Nurse
# 9065        9065                                    Systems Analyst
# 9066        9066  Sales & Marketing Team Lead - Competative Spor...
#
#                                     Deskripsi Pekerjaan  \
# 0     EducationBachelor's DegreeSkillsSQLTime Manage...
# ...

# %%
df2.set_index('Nama Pekerjaan')
# Out:
#                                                     Unnamed: 0  \
# Nama Pekerjaan
# Data Scientist (NiFi, DHF)                                   0
# Data Scientist - Defense & Intelligence                      1
# Fall 2019/Winter 2020 Applied Science Machine L...           2
# Applied Scientist Fall/Winter 2019 Internship -...           3
# Data Scientist/Engineer (HDF, NiFi)                          4
# ...                                                        ...
# Senior Business Services Analyst                          9062
# AVP of Corporate Strategy & Business Strategy             9063
# Business Analyst - Registered Nurse                       9064
# Systems Analyst                                           9065
# Sales & Marketing Team Lead - Competative Sport...        9066
#
#                                                                                   Deskripsi Pekerjaan  \
# Nama Pekerjaan
# ...
