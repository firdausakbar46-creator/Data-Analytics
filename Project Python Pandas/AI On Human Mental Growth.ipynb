# %% [markdown]
# # Project 3

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\data analytics project 1\project analysis python\AI_Impact_on_Human_Mental_Growth.csv")
df
# Out:
#        Row_ID  Year                          Era     Scenario          Region  \
# 0           1  2064   Symbiotic Intelligence Age  Pessimistic       East Asia
# 1           2  2029       AI Mainstream Adoption        Mixed   Latin America
# 2           3  2047  Post-Singularity Transition      Neutral   Latin America
# 3           4  2069   Symbiotic Intelligence Age      Neutral       East Asia
# 4           5  2048  Post-Singularity Transition   Optimistic      South Asia
# ...       ...   ...                          ...          ...             ...
# 51995   51996  2069   Symbiotic Intelligence Age        Mixed      South Asia
# 51996   51997  2052       Cognitive Co-Evolution  Pessimistic      South Asia
# 51997   51998  2034         AI-Augmented Society        Mixed  Southeast Asia
# 51998   51999  2063   Symbiotic Intelligence Age        Mixed          Europe
# 51999   52000  2052       Cognitive Co-Evolution  Pessimistic       East Asia
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Row_ID                             52000 non-null  int64
#  1   Year                               52000 non-null  int64
#  2   Era                                52000 non-null  object
#  3   Scenario                           52000 non-null  object
#  4   Region                             52000 non-null  object
#  5   Demographic_Group                  52000 non-null  object
#  6   Education_Level                    52000 non-null  object
#  7   Profession                         52000 non-null  object
#  8   AI_Tool_Category                   44286 non-null  object
#  9   Weekly_AI_Usage_Hours              52000 non-null  float64
#  10  AI_Dependency_Score                52000 non-null  float64
# ...

# %%
df.describe()
# Out:
#              Row_ID          Year  Weekly_AI_Usage_Hours  AI_Dependency_Score  \
# count  52000.000000  52000.000000           52000.000000         52000.000000
# mean   26000.500000   2049.493077              24.568075            49.063843
# std    15011.251336     15.027805              11.923980            21.789630
# min        1.000000   2024.000000               0.000000             0.110000
# 25%    13000.750000   2036.000000              15.300000            31.170000
# 50%    26000.500000   2049.000000              24.500000            49.045000
# 75%    39000.250000   2063.000000              33.700000            67.070000
# max    52000.000000   2075.000000              62.200000            99.960000
#
#        Human_Creativity_Score  Critical_Thinking_Ability  \
# count            52000.000000               52000.000000
# mean                63.437188                  63.135306
# std                 12.205201                  12.404421
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51995    False
# 51996    False
# 51997    False
# 51998    False
# 51999    False
# Length: 52000, dtype: bool

# %%
df.isnull().mean()
# Out:
# Row_ID                               0.000000
# Year                                 0.000000
# Era                                  0.000000
# Scenario                             0.000000
# Region                               0.000000
# Demographic_Group                    0.000000
# Education_Level                      0.000000
# Profession                           0.000000
# AI_Tool_Category                     0.148346
# Weekly_AI_Usage_Hours                0.000000
# AI_Dependency_Score                  0.000000
# Human_Creativity_Score               0.000000
# Critical_Thinking_Ability            0.000000
# Problem_Solving_Skills               0.000000
# Emotional_Intelligence               0.000000
# Innovation_Rate                      0.000000
# Learning_Speed                       0.000000
# Human_Decision_Making_Involvement    0.000000
# Social_Interaction_Quality           0.000000
# Cognitive_Load_Index                 0.000000
# ...

# %%
df
# Out:
#        Row_ID  Year                          Era     Scenario          Region  \
# 0           1  2064   Symbiotic Intelligence Age  Pessimistic       East Asia
# 1           2  2029       AI Mainstream Adoption        Mixed   Latin America
# 2           3  2047  Post-Singularity Transition      Neutral   Latin America
# 3           4  2069   Symbiotic Intelligence Age      Neutral       East Asia
# 4           5  2048  Post-Singularity Transition   Optimistic      South Asia
# ...       ...   ...                          ...          ...             ...
# 51995   51996  2069   Symbiotic Intelligence Age        Mixed      South Asia
# 51996   51997  2052       Cognitive Co-Evolution  Pessimistic      South Asia
# 51997   51998  2034         AI-Augmented Society        Mixed  Southeast Asia
# 51998   51999  2063   Symbiotic Intelligence Age        Mixed          Europe
# 51999   52000  2052       Cognitive Co-Evolution  Pessimistic       East Asia
#
# ...

# %%
df.rename(columns = {'Year':'Tahun', 'Era':'Masa', 'Scenario':'Skenario'})
# Out:
#        Row_ID  Tahun                         Masa     Skenario  \
# 0           1   2064   Symbiotic Intelligence Age  Pessimistic
# 1           2   2029       AI Mainstream Adoption        Mixed
# 2           3   2047  Post-Singularity Transition      Neutral
# 3           4   2069   Symbiotic Intelligence Age      Neutral
# 4           5   2048  Post-Singularity Transition   Optimistic
# ...       ...    ...                          ...          ...
# 51995   51996   2069   Symbiotic Intelligence Age        Mixed
# 51996   51997   2052       Cognitive Co-Evolution  Pessimistic
# 51997   51998   2034         AI-Augmented Society        Mixed
# 51998   51999   2063   Symbiotic Intelligence Age        Mixed
# 51999   52000   2052       Cognitive Co-Evolution  Pessimistic
#
#                Region    Demographic_Group Education_Level  \
# 0           East Asia  Young Adult (26-35)   Undergraduate
# 1       Latin America       Senior (51-65)   Undergraduate
# ...

# %%
df.set_index('Region')
# Out:
#                 Row_ID  Year                          Era     Scenario  \
# Region
# East Asia            1  2064   Symbiotic Intelligence Age  Pessimistic
# Latin America        2  2029       AI Mainstream Adoption        Mixed
# Latin America        3  2047  Post-Singularity Transition      Neutral
# East Asia            4  2069   Symbiotic Intelligence Age      Neutral
# South Asia           5  2048  Post-Singularity Transition   Optimistic
# ...                ...   ...                          ...          ...
# South Asia       51996  2069   Symbiotic Intelligence Age        Mixed
# South Asia       51997  2052       Cognitive Co-Evolution  Pessimistic
# Southeast Asia   51998  2034         AI-Augmented Society        Mixed
# Europe           51999  2063   Symbiotic Intelligence Age        Mixed
# East Asia        52000  2052       Cognitive Co-Evolution  Pessimistic
#
#                   Demographic_Group Education_Level          Profession  \
# Region
# ...

# %%
df.pivot_table(index= 'Demographic_Group', columns= 'Region',values= 'Weekly_AI_Usage_Hours')
# Out:
# Region                  Africa  East Asia     Europe  Latin America  \
# Demographic_Group
# Adult (36-50)        24.585389  24.294850  24.527521      25.261374
# Elder (65+)          23.970052  24.389580  24.660051      24.098309
# Senior (51-65)       24.013386  24.302726  24.412999      24.859445
# Young Adult (26-35)  24.384228  23.826463  23.966943      24.787544
# Youth (18-25)        24.896777  24.418966  25.014662      24.321913
#
# Region               Middle East  North America    Oceania  South Asia  \
# Demographic_Group
# Adult (36-50)          25.321289      24.598361  24.642774   24.895341
# Elder (65+)            24.016637      24.607611  24.376740   24.857241
# Senior (51-65)         24.193523      24.852632  24.967313   24.550613
# Young Adult (26-35)    24.593707      25.130177  24.988808   24.783731
# Youth (18-25)          24.373427      24.431771  25.143034   24.476000
#
# Region               Southeast Asia
# Demographic_Group
# ...

# %%
df
# Out:
#        Row_ID  Year                          Era     Scenario          Region  \
# 0           1  2064   Symbiotic Intelligence Age  Pessimistic       East Asia
# 1           2  2029       AI Mainstream Adoption        Mixed   Latin America
# 2           3  2047  Post-Singularity Transition      Neutral   Latin America
# 3           4  2069   Symbiotic Intelligence Age      Neutral       East Asia
# 4           5  2048  Post-Singularity Transition   Optimistic      South Asia
# ...       ...   ...                          ...          ...             ...
# 51995   51996  2069   Symbiotic Intelligence Age        Mixed      South Asia
# 51996   51997  2052       Cognitive Co-Evolution  Pessimistic      South Asia
# 51997   51998  2034         AI-Augmented Society        Mixed  Southeast Asia
# 51998   51999  2063   Symbiotic Intelligence Age        Mixed          Europe
# 51999   52000  2052       Cognitive Co-Evolution  Pessimistic       East Asia
#
# ...

# %% [markdown]
# # pilih kolom, hapus kolom, tambah kolom, stat corr, vis:  bar and line chart

# %%
df[['Year','Region','Profession']]
# Out:
#        Year          Region          Profession
# 0      2064       East Asia          Technology
# 1      2029   Latin America          Healthcare
# 2      2047   Latin America  Science & Research
# 3      2069       East Asia          Technology
# 4      2048      South Asia    Entrepreneurship
# ...     ...             ...                 ...
# 51995  2069      South Asia          Technology
# 51996  2052      South Asia      Skilled Trades
# 51997  2034  Southeast Asia          Technology
# 51998  2063          Europe            Business
# 51999  2052       East Asia         Engineering
#
# [52000 rows x 3 columns]

# %%
df
# Out:
#        Row_ID  Year                          Era     Scenario          Region  \
# 0           1  2064   Symbiotic Intelligence Age  Pessimistic       East Asia
# 1           2  2029       AI Mainstream Adoption        Mixed   Latin America
# 2           3  2047  Post-Singularity Transition      Neutral   Latin America
# 3           4  2069   Symbiotic Intelligence Age      Neutral       East Asia
# 4           5  2048  Post-Singularity Transition   Optimistic      South Asia
# ...       ...   ...                          ...          ...             ...
# 51995   51996  2069   Symbiotic Intelligence Age        Mixed      South Asia
# 51996   51997  2052       Cognitive Co-Evolution  Pessimistic      South Asia
# 51997   51998  2034         AI-Augmented Society        Mixed  Southeast Asia
# 51998   51999  2063   Symbiotic Intelligence Age        Mixed          Europe
# 51999   52000  2052       Cognitive Co-Evolution  Pessimistic       East Asia
#
# ...

# %%
df = df.drop(columns= ['Learning_Speed','Human_Decision_Making_Involvement','Social_Interaction_Quality'])
df
# Out:
#        Row_ID  Year                          Era     Scenario          Region  \
# 0           1  2064   Symbiotic Intelligence Age  Pessimistic       East Asia
# 1           2  2029       AI Mainstream Adoption        Mixed   Latin America
# 2           3  2047  Post-Singularity Transition      Neutral   Latin America
# 3           4  2069   Symbiotic Intelligence Age      Neutral       East Asia
# 4           5  2048  Post-Singularity Transition   Optimistic      South Asia
# ...       ...   ...                          ...          ...             ...
# 51995   51996  2069   Symbiotic Intelligence Age        Mixed      South Asia
# 51996   51997  2052       Cognitive Co-Evolution  Pessimistic      South Asia
# 51997   51998  2034         AI-Augmented Society        Mixed  Southeast Asia
# 51998   51999  2063   Symbiotic Intelligence Age        Mixed          Europe
# 51999   52000  2052       Cognitive Co-Evolution  Pessimistic       East Asia
#
# ...
